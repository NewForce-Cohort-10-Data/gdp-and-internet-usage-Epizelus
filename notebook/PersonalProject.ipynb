# %% [raw]
# 3.

# %%
import pandas as pd   
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')
gdp_df.tail()
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 8214        Zimbabwe  1994  3965.730986              NaN
# 8215        Zimbabwe  1993  3634.750494              NaN
# 8216        Zimbabwe  1992  3649.891947              NaN
# 8217        Zimbabwe  1991  4126.405247              NaN
# 8218        Zimbabwe  1990  4013.299059              NaN

# %%
	Country or Area	Year	Value	Value Footnotes
8214	Zimbabwe	1994	3965.730986	NaN
8215	Zimbabwe	1993	3634.750494	NaN
8216	Zimbabwe	1992	3649.891947	NaN
8217	Zimbabwe	1991	4126.405247	NaN
8218	Zimbabwe	1990	4013.299059	NaN
# Out:
#   Cell In[5], line 1
#     Country or Area	Year	Value	Value Footnotes
#                    	^
# SyntaxError: invalid syntax

# %%
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %% [markdown]
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
new_gdp = gdp_df.drop(columns = ['Value Footnotes'])
new_gdp.columns
# Out:
# Index(['Country or Area', 'Year', 'Value'], dtype='object')

# %% [markdown]
# Index(['Country or Area', 'Year', 'Value'], dtype='object')

# %%
new_gdp.columns = ['Country','Year','GDP_Per_Capita']
new_gdp = new_gdp[new_gdp['Year'] == 2020]
new_gdp.head()
# Out:
#                          Country  Year  GDP_Per_Capita
# 3                    Afghanistan  2020     2769.685745
# 27   Africa Eastern and Southern  2020     3861.111238
# 61    Africa Western and Central  2020     4622.731427
# 95                       Albania  2020    14650.395929
# 129                      Algeria  2020    14194.155748

# %% [markdown]
# Country	Year	GDP_Per_Capita
# 0	Afghanistan	2023	1992.424394
# 1	Afghanistan	2022	1981.710168
# 2	Afghanistan	2021	2144.166570
# 3	Afghanistan	2020	2769.685745
# 4	Afghanistan	2019	2927.245144

# %%
new_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 247 entries, 3 to 8188
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         247 non-null    object
#  1   Year            247 non-null    int64
#  2   GDP_Per_Capita  247 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 7.7+ KB

# %%
new_gdp.describe()
# Out:
#          Year  GDP_Per_Capita
# count   247.0      247.000000
# mean   2020.0    23044.942556
# std       0.0    22856.889868
# min    2020.0      833.920257
# 25%    2020.0     5857.324918
# 50%    2020.0    15309.235988
# 75%    2020.0    34823.614188
# max    2020.0   128256.560341

# %%
country_years = new_gdp.Year.value_counts()
country_years
# Out:
# Year
# 2020    247
# Name: count, dtype: int64

# %%
plt.boxplot(x=new_gdp['GDP_Per_Capita'], vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b94e7c5c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b952dd1250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b95655fdd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b952dd1b80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b952dd1820>],
#  'means': []}

# %%
new_gdp['GDP_Per_Capita'].hist()
plt.title('GDP Per Capita in the Year 2020')
# Out:
# Text(0.5, 1.0, 'GDP Per Capita in the Year 2020')

# %%
new_gdp.describe()
# Out:
#          Year  GDP_Per_Capita
# count   247.0      247.000000
# mean   2020.0    23044.942556
# std       0.0    22856.889868
# min    2020.0      833.920257
# 25%    2020.0     5857.324918
# 50%    2020.0    15309.235988
# 75%    2020.0    34823.614188
# max    2020.0   128256.560341

# %%
sns.violinplot(x=new_gdp['Year'],y=new_gdp['GDP_Per_Capita'])
# Out:
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %%
new_gdp.GDP_Per_Capita.plot.density(color='green') 
plt.title('Density plot for GDP Per Capita') 
plt.show()

# %% [raw]
# 10. For this question, you're going to create some visualizations to compare GDP per capita values for the years 1990, 2000, 2010, and 2020. Start by subsetting your data to just these 4 years into a new DataFrame named gdp_decades. Using this, create the following 4 plots:

# %%
years = [1990, 2000, 2010, 2020]
gdp_years = gdp_df.drop(columns= ['Value Footnotes'])
gdp_years.columns = ['Country','Year','GDP_Per_Capita']
gdp_years = gdp_years[gdp_years['Year'].isin(years)]
gdp_years.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 965 entries, 3 to 8218
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country         965 non-null    object
#  1   Year            965 non-null    int64
#  2   GDP_Per_Capita  965 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.2+ KB

# %%
sns.barplot(x="Year", y="GDP_Per_Capita", data=gdp_years)
plt.title('GDP Per Capita') 
plt.show()

# %%
gdp_years.plot.scatter("Year","GDP_Per_Capita")
plt.title('GDP Per Capita') 
plt.show()

# %%
sns.boxplot(x="Year", y="GDP_Per_Capita", data=gdp_years)
plt.title('GDP Per Capita') 
plt.show()

# %% [markdown]
# 14. Read in the internet use dataset into a DataFrame named `internet_df`.

# %%
internet_df = pd.read_csv('../data/internet_use.csv', nrows=6083)

# %% [markdown]
# Once you are able to read it in, take per a look at the top and bottom few rows to make sure that it has been read in correctly. Also, check the datatypes of the columns.

# %%
internet_df.head()
# Out:
#   Country or Area  Year  Value Value Footnotes
# 0     Afghanistan  2019  17.60               1
# 1     Afghanistan  2018  16.80               2
# 2     Afghanistan  2017  13.50               3
# 3     Afghanistan  2016  11.00               4
# 4     Afghanistan  2015   8.26               4

# %%
internet_df.tail()
# Out:
#      Country or Area  Year     Value Value Footnotes
# 6078        Zimbabwe  1997  0.033080             NaN
# 6079        Zimbabwe  1996  0.016790             NaN
# 6080        Zimbabwe  1995  0.007684             NaN
# 6081        Zimbabwe  1994  0.001739             NaN
# 6082        Zimbabwe  1990  0.000000             NaN

# %%
internet_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6083 entries, 0 to 6082
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  6083 non-null   object
#  1   Year             6083 non-null   int64
#  2   Value            6083 non-null   float64
#  3   Value Footnotes  2826 non-null   object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 190.2+ KB

# %% [raw]
# 15. Drop the `Value Footnotes` column and rename the remaining three to 'Country', 'Year', and 'Internet_Users_Pct'.

# %%
internet_use = internet_df.drop(columns = ['Value Footnotes'])
internet_use.columns =['Country', 'Year', 'Internet_Users_Pct']
internet_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6083 entries, 0 to 6082
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             6083 non-null   object
#  1   Year                6083 non-null   int64
#  2   Internet_Users_Pct  6083 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 142.7+ KB

# %% [markdown]
# 16. Look at the number of observations in this dataset per year. What do you notice?

# %%
us_internet = internet_use[(internet_use['Country']=='United States')]
us_internet = internet_use[(internet_use['Year'].isin(years))] 
sns.barplot(x='Year',y='Internet_Users_Pct',data=us_internet)
# Out:
# <Axes: xlabel='Year', ylabel='Internet_Users_Pct'>
